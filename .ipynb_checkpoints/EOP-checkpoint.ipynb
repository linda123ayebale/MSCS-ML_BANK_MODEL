# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
from IPython.display import display, HTML
html_code = """ 
<h1 style ="color:Green">Reading the Data</h1>
"""
display(HTML(html_code))
# Out:
#
# <h1 style ="color:Green">Reading the Data</h1>

# %%
df = pd.read_csv("bank.csv",sep=';')

# %%
from IPython.display import display, HTML
html_code = """ 
<h3 style ="color:Green">Head</h3>
"""
display(HTML(html_code))
# Out:
#
# <h3 style ="color:Green">Head</h3>

# %%
df.head(100)
# Out:
#     age          job   marital  education default  balance housing loan  \
# 0    30   unemployed   married    primary      no     1787      no   no
# 1    33     services   married  secondary      no     4789     yes  yes
# 2    35   management    single   tertiary      no     1350     yes   no
# 3    30   management   married   tertiary      no     1476     yes  yes
# 4    59  blue-collar   married  secondary      no        0     yes   no
# ..  ...          ...       ...        ...     ...      ...     ...  ...
# 95   41      unknown    single   tertiary      no     1567      no   no
# 96   41       admin.   married   tertiary      no     5426     yes   no
# 97   30       admin.    single   tertiary      no      261      no   no
# 98   36  blue-collar  divorced  secondary      no     2843      no   no
# 99   31   unemployed    single    primary      no      406      no   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
from IPython.display import display, HTML
html_code = """ 
<h3 style ="color:Green">Head</h3>
"""
display(HTML(html_code))
# Out:
#
# <h3 style ="color:Green">Head</h3>

# %%
df.tail()
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no

# %%
from IPython.display import display, HTML
html_code = """ 
<h1 style ="color:Green">Sanity Check of the data</h2>
"""
display(HTML(html_code))
# Out:
#
# <h1 style ="color:Green">Sanity Check of the data</h2>

# %%
from IPython.display import display, HTML
html_code = """ 
<h3 style ="color:Green">Shape</h3>
"""
display(HTML(html_code))
# Out:
#
# <h3 style ="color:Green">Shape</h3>

# %%
df.shape
# Out:
# (4521, 17)

# %%
from IPython.display import display, HTML
html_code = """ 
<h3 style ="color:Green">Getting all the information about the data using info</h3>
"""
display(HTML(html_code))
# Out:
#
# <h3 style ="color:Green">Getting all the information about the data using info</h3>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
from IPython.display import display, HTML
html_code = """ 
<h3 style ="color:Green">Finding the missing value</h3>
"""
display(HTML(html_code))
# Out:
#
# <h3 style ="color:Green">Finding the missing value</h3>

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
from IPython.display import display, HTML
html_code = """ 
<h3 style ="color:Green">Percentage of missing values</h3>
"""
display(HTML(html_code))
# Out:
#
# <h3 style ="color:Green">Percentage of missing values</h3>

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# age          0.0
# job          0.0
# marital      0.0
# education    0.0
# default      0.0
# balance      0.0
# housing      0.0
# loan         0.0
# contact      0.0
# day          0.0
# month        0.0
# duration     0.0
# campaign     0.0
# pdays        0.0
# previous     0.0
# poutcome     0.0
# y            0.0
# dtype: float64

# %%
from IPython.display import display, HTML
html_code = """ 
<h3 style ="color:Green">Finding duplicate values</h3>
"""
display(HTML(html_code))
# Out:
#
# <h3 style ="color:Green">Finding duplicate values</h3>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from IPython.display import display, HTML
html_code = """ 
<h3 style ="color:Green">Finding garbage values</h3>
"""
display(HTML(html_code))
# Out:
#
# <h3 style ="color:Green">Finding garbage values</h3>

# %%
# Get gabbage values in all object datatype columns
for i in df.select_dtypes(include ="object").columns:
    print(df[i].value_counts())
    print("***"*10)
# Out:
# job
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: count, dtype: int64
# ******************************
# marital
# married     2797
# single      1196
# divorced     528
# Name: count, dtype: int64
# ******************************
# education
# secondary    2306
# tertiary     1350
# primary       678
# unknown       187
# Name: count, dtype: int64
# ******************************
# default
# no     4445
# yes      76
# Name: count, dtype: int64
# ******************************
# housing
# yes    2559
# no     1962
# Name: count, dtype: int64
# ******************************
# loan
# no     3830
# yes     691
# Name: count, dtype: int64
# ******************************
# contact
# cellular     2896
# unknown      1324
# telephone     301
# ...

# %%
from IPython.display import display, HTML
html_code = """ 
<h1 style ="color:Green">Exploratory Data Analysis(EDA)</h1>
"""
display(HTML(html_code))
# Out:
#
# <h1 style ="color:Green">Exploratory Data Analysis(EDA)</h1>

# %%
from IPython.display import display, HTML
html_code = """ 
<h3 style ="color:Green">descriptive statistics</h3>
"""
display(HTML(html_code))
# Out:
#
# <h3 style ="color:Green">descriptive statistics</h3>

# %%
from IPython.display import display, HTML
html_code = """ 
<h4 style ="color:Green">descriptive statistics of integer columns</h4>
"""
display(HTML(html_code))
# Out:
#
# <h4 style ="color:Green">descriptive statistics of integer columns</h4>

# %%
df.describe().T
# Out:
#            count         mean          std     min    25%    50%     75%  \
# age       4521.0    41.170095    10.576211    19.0   33.0   39.0    49.0
# balance   4521.0  1422.657819  3009.638142 -3313.0   69.0  444.0  1480.0
# day       4521.0    15.915284     8.247667     1.0    9.0   16.0    21.0
# duration  4521.0   263.961292   259.856633     4.0  104.0  185.0   329.0
# campaign  4521.0     2.793630     3.109807     1.0    1.0    2.0     3.0
# pdays     4521.0    39.766645   100.121124    -1.0   -1.0   -1.0    -1.0
# previous  4521.0     0.542579     1.693562     0.0    0.0    0.0     0.0
#
#               max
# age          87.0
# balance   71188.0
# day          31.0
# duration   3025.0
# campaign     50.0
# pdays       871.0
# previous     25.0

# %%
from IPython.display import display, HTML
html_code = """ 
<h4 style ="color:Green">descriptive statistics of object columns</h4>
"""
display(HTML(html_code))
# Out:
#
# <h4 style ="color:Green">descriptive statistics of object columns</h4>

# %%
df.describe(include="object")
# Out:
#                job  marital  education default housing  loan   contact month  \
# count         4521     4521       4521    4521    4521  4521      4521  4521
# unique          12        3          4       2       2     2         3    12
# top     management  married  secondary      no     yes    no  cellular   may
# freq           969     2797       2306    4445    2559  3830      2896  1398
#
#        poutcome     y
# count      4521  4521
# unique        4     2
# top     unknown    no
# freq       3705  4000

# %%
from IPython.display import display, HTML
html_code = """ 
<h4 style ="color:Green">understand the distribution using the histogram</h4>
"""
display(HTML(html_code))
# Out:
#
# <h4 style ="color:Green">understand the distribution using the histogram</h4>

# %%
for i in df.select_dtypes(include="number").columns:
    sns.histplot(data=df, x=i)
    plt.show()

# %%
from IPython.display import display, HTML
html_code = """ 
<h2 style ="color:Green">Identifying the outliers using boxplot</h2>
<h2 style ="color:Green">Questions</h2>
<h2 style ="color:Green">Do the outliers represent a significant number of individuals in the dataset?
</h2>
<h2 style ="color:Green">What specific characteristics define the outliers in the context of this dataset?

</h2>




"""
display(HTML(html_code))
# Out:
#
# <h2 style ="color:Green">Identifying the outliers using boxplot</h2>
# <h2 style ="color:Green">Questions</h2>
# <h2 style ="color:Green">Do the outliers represent a significant number of individuals in the dataset?
# </h2>
# <h2 style ="color:Green">What specific characteristics define the outliers in the context of this dataset?
#
# </h2>

# %%
for i in df.select_dtypes(include="number").columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
from IPython.display import display, HTML
html_code = """ 
<h4 style ="color:Green">Identifying the relationships using scatterplot</h4>
"""
display(HTML(html_code))
# Out:
#
# <h4 style ="color:Green">Identifying the relationships using scatterplot</h4>

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
for i in ['balance', 'day', 'duration', 'campaign', 'pdays', 'previous']:
    sns.scatterplot(data=df,x=i,y='age')
    plt.show()

# %%
from IPython.display import display, HTML
html_code = """ 
<h4 style ="color:Green">Correlation with heatmap to interprete the relation and the multicolliniarity</h4>
"""
display(HTML(html_code))
# Out:
#
# <h4 style ="color:Green">Correlation with heatmap to interprete the relation and the multicolliniarity</h4>

# %%
s=df.select_dtypes(include="number").corr()

# %%
# better size of the heatmap
plt.figure(figsize=(10,10))

sns.heatmap(s,annot=True)
# Out:
# <Axes: >
